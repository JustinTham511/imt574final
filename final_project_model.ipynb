# %%
import pandas as pd

# %%
df = pd.read_csv('stayzilla_sample.csv')
df
# Out:
#                                         additional_info  \
# 0     Acceptance Rate:100 percent|Response Time:< 6 ...
# 1     Acceptance Rate:100 percent|Response Time:< 6 ...
# 2     Acceptance Rate:100 percent|Response Time:< 6 ...
# 3     Acceptance Rate:100 percent|Response Time:< 6 ...
# 4     Acceptance Rate:100 percent|Response Time:< 6 ...
# ...                                                 ...
# 1202  ~ All Taxes.~ Complimentary Bed Tea.~ Complime...
# 1203                                        ~ All Taxes
# 1204  Kindly Note ~ Hotel doesn't have Restaurants i...
# 1205  ~ All taxes.~ Complimentary WiFi. And Bed Tea;...
# 1206                                                NaN
#
#                                               amenities check_in_date  \
# 0                                             Newspaper    04-08-2016
# 1                                            Parking|AC    04-08-2016
# 2                              Pickup & Drop|Parking|AC    04-08-2016
# 3           WiFi|Newspaper|Pickup & Drop|Gym|Parking|AC    04-08-2016
# 4                                          Newspaper|AC    04-08-2016
# ...                                                 ...           ...
# 1202  Restaurent | Business Center | Wifi | Swimming...    06/01/2016
# 1203                       Wifi | Laundry | Car Parking    06/01/2016
# 1204                              Laundry | Car Parking    06/01/2016
# 1205  Wifi | Credit Card | Laundry | Free Newspaper ...    06/01/2016
# 1206          Bar/Pub | Wifi | Laundry | Free Newspaper    06/01/2016
#
#      check_out_date         city country  crawl_date  \
# 0        05-08-2016    Kalimpong   India  2016-07-20
# 1        05-08-2016       Kanpur   India  2016-07-20
# 2        05-08-2016      Jodhpur   India  2016-07-20
# 3        05-08-2016   Jalpaiguri   India  2016-07-20
# 4        05-08-2016       Kanpur   India  2016-07-20
# ...             ...          ...     ...         ...
# 1202     09/01/2016        Mandi     NaN         NaN
# 1203     09/01/2016     Bhilwara     NaN         NaN
# 1204     09/01/2016  Gandhinagar     NaN         NaN
# 1205     09/01/2016   Uttarkashi     NaN         NaN
# 1206     09/01/2016          Goa     NaN         NaN
#
#                                             description  \
# 0     Sangsey Valley Resort is Located at the wonder...
# 1     What should you know? Enjoy unmatched service ...
# 2     What should you know? A budget hotel, this acc...
# 3     What should you know? The Riverwood Forest Ret...
# 4     What should you know? Located at a walking dis...
# ...                                                 ...
# 1202                                                NaN
# 1203                                                NaN
# 1204                                                NaN
# 1205                                                NaN
# 1206                                                NaN
#
#                                         highlight_value  hotel_star_rating  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# ...                                                 ...                ...
# 1202  What should you know?\n Midway resort, as the ...                0.0
# 1203  What should you know?\n A budget hotel that of...                0.0
# 1204  What should you know?\n Hotel Shreeji boasts o...                0.0
# 1205                                                NaN                0.0
# 1206                                                NaN                0.0
#
#       ...           query_time_stamp               room_price  \
# 0     ...  2016-07-20 10:59:55 +0000  3167per night incl. tax
# 1     ...  2016-07-20 10:59:55 +0000   815per night incl. tax
# 2     ...  2016-07-20 10:59:55 +0000  1624per night incl. tax
# 3     ...  2016-07-20 10:59:55 +0000  3509per night incl. tax
# 4     ...  2016-07-20 10:59:55 +0000  5802per night incl. tax
# ...   ...                        ...                      ...
# 1202  ...  2015-12-30 15:21:16 +0000                      NaN
# 1203  ...  2015-12-30 15:21:16 +0000                      NaN
# 1204  ...  2015-12-30 15:21:16 +0000                      NaN
# 1205  ...  2015-12-30 15:21:16 +0000                      NaN
# 1206  ...  2015-12-30 15:21:16 +0000                      NaN
#
#                                              room_types  search_term  \
# 0                                         3 Bedded Room          NaN
# 1                                  Double Non-A/C Rooms          NaN
# 2                                      Deluxe AC Double          NaN
# 3                                    Premium Single A/c          NaN
# 4                                      Deluxe AC Double          NaN
# ...                                                 ...          ...
# 1202  Deluxe Room Non Ac | Deluxe Room Ac | Super De...        Mandi
# 1203          Deluxe Double | Luxury Double | Extra Bed     Bhilwara
# 1204  Double Non A/c Room | Double A/c Room | Extra Bed  Gandhinagar
# 1205  Double Non A/c Room | Deluxe Non A/c Double | ...   Uttarkashi
# 1206  Duplex Upstairs Hut Double | Duplex Downstairs...    Goa Velha
#
#                                           service_value  \
# 0                                          Not Verified
# 1                                          Not Verified
# 2                                          Not Verified
# 3                                          Not Verified
# 4                                          Not Verified
# ...                                                 ...
# 1202                 Laundry | Free Newspaper | Parking
# 1203  Laundry | Parking | 24 hour check in | 24 hour...
# 1204                                  Laundry | Parking
# 1205  Laundry | Free Newspaper | Parking | 24 hour c...
# 1206                           Laundry | Free Newspaper
#
#                                           similar_hotel           sitename  \
# 0                                                   NaN  www.stayzilla.com
# 1                Hotel Mangalam|Hotel Maha Roopa Palace  www.stayzilla.com
# 2     Gouri Heritage Haveli|The Regent Hotel|Vista R...  www.stayzilla.com
# 3                                                   NaN  www.stayzilla.com
# 4                                     Hotel Royal Cliff  www.stayzilla.com
# ...                                                 ...                ...
# 1202                                                NaN          stayzilla
# 1203                                                NaN          stayzilla
# 1204                                                NaN          stayzilla
# 1205                                                NaN          stayzilla
# 1206                                                NaN          stayzilla
#
#                                   things_to_do  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 1202  Restaurant | Swimming Pool | Health Club
# 1203                                       NaN
# 1204                                       NaN
# 1205                                       NaN
# 1206                                       Bar
#
#                                          things_to_note  \
# 0     All taxes.|Complimentary Breakfast, Lunch and ...
# 1     Kindly Note:|This Tariff is not applicable for...
# 2                         All taxes.|Complimentary Tea.
# 3     All taxes|Complimentary Breakfast|Kindly Note:...
# 4     Complimentary Breakfast.|Complimentary WiFi.|C...
# ...                                                 ...
# 1202                                                NaN
# 1203                                                NaN
# 1204                                                NaN
# 1205                                                NaN
# 1206                                                NaN
#
#                                uniq_id
# 0     52a63c632d90923f7f0c394a79dce191
# 1     49ad3256fc231a4c9fdb6f6f2cc00d16
# 2     8b5952e578717e20b311846f7aab031f
# 3     032d715cabef6d4633e753de416929a8
# 4     ed546591dba770faae0ec3edadb0fcde
# ...                                ...
# 1202  8cdac0cb8c7c71a1731370750b5448f0
# 1203  d091b4973071cbc2559c0db555db80f3
# 1204  9fb6e2266ea09509d668195b1250eed1
# 1205  6376a5202298fb78e0f9954a85b8a45c
# 1206  8d1913cb412923244fb6c5c333a3d8d1
#
# [1207 rows x 33 columns]

# %%
df['cleaned_price'] = df['room_price'].str.replace('per night incl. tax', '')
df['cleaned_price'] = pd.to_numeric(df['cleaned_price'], errors='coerce').fillna(0).astype(int)
# df.head()
# df.info()

# %%
print(df['cleaned_price'])
# Out:
# 0       3167
# 1        815
# 2       1624
# 3       3509
# 4       5802
#         ...
# 1202       0
# 1203       0
# 1204       0
# 1205       0
# 1206       0
# Name: cleaned_price, Length: 1207, dtype: int64

# %%
print(df['occupancy'])
# Out:
# 0       3 Adults 2 Kids
# 1       2 Adults 2 Kids
# 2       2 Adults 2 Kids
# 3        1 Adult 2 Kids
# 4       2 Adults 2 Kids
#              ...
# 1202                NaN
# 1203                NaN
# 1204                NaN
# 1205                NaN
# 1206                NaN
# Name: occupancy, Length: 1207, dtype: object

# %%
df[['adults', 'kids']] = df['occupancy'].str.extract(r'(?i)(\d+) adults?\s*(\d*) kids?')
df[['adults', 'kids']] = df[['adults', 'kids']].apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)
# df.head()

# %%
# How does occupancy affect the room price of a property?
# Linear regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df['cleaned_price'].info()
df['adults'].info()
df['kids'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1207 entries, 0 to 1206
# Series name: cleaned_price
# Non-Null Count  Dtype
# --------------  -----
# 1207 non-null   int64
# dtypes: int64(1)
# memory usage: 9.6 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 1207 entries, 0 to 1206
# Series name: adults
# Non-Null Count  Dtype
# --------------  -----
# 1207 non-null   int64
# dtypes: int64(1)
# memory usage: 9.6 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 1207 entries, 0 to 1206
# Series name: kids
# Non-Null Count  Dtype
# --------------  -----
# 1207 non-null   int64
# dtypes: int64(1)
# memory usage: 9.6 KB

# %%
X = df[['adults', 'kids']]
y = df['cleaned_price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
lr_model = sm.OLS(y, sm.add_constant(X)).fit()
print(lr_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          cleaned_price   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     27.65
# Date:                Thu, 27 Feb 2025   Prob (F-statistic):           1.82e-12
# Time:                        12:40:59   Log-Likelihood:                -11775.
# No. Observations:                1207   AIC:                         2.356e+04
# Df Residuals:                    1204   BIC:                         2.357e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        964.0661    319.272      3.020      0.003     337.675    1590.457
# adults       673.0775     93.989      7.161      0.000     488.678     857.477
# kids           6.3298    184.317      0.034      0.973    -355.289     367.949
# ==============================================================================
# Omnibus:                     2469.119   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6204332.325
# Skew:                          16.098   Prob(JB):                         0.00
# Kurtosis:                     352.758   Cond. No.                         8.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Linear regression equation is:
# y = 964.07 + (673.08 * x1) + (6.33 * x2)
# Adults has a p-value of 0.000 which is statistically significant since it is less than 0.05. While kids has a p-value of 0.973 which is not statistically significant. Meaning that kids has does have as strong influence on room prices.
